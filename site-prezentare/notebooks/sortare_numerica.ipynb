# %%
print('OK')

# %% [markdown]
# # Sortare numere prin algoritm genetic
#
# Acesta este un exemplu fortat, deoarece din punct de vedere al eficientei sau complexitatii, nu reuseste sa fie nici macar egal cu sortarea liniara.
